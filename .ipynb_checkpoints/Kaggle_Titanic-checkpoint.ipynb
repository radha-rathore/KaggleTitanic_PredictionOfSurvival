# %% [markdown]
# ### Kaggle: Titanic
# The competition is simple: use machine learning to create a model that predicts which passengers survived the Titanic shipwreck.
#
# ### Features
#
# 1. survival: Survival  -> 0 = No, 1 = Yes
# 2. pclass: Ticket class ->	1 = 1st, 2 = 2nd, 3 = 3rd
# 3. sex:	Sex
# 4. Age: Age in years
# 5. sibsp: # of siblings / spouses aboard the Titanic
# 6. parch: # of parents / children aboard the Titanic
# 7. ticket: Ticket number
# 8. fare: Passenger fare
# 9. cabin: Cabin number
# 10. embarked: Port of Embarkation	 -> C = Cherbourg, Q = Queenstown, S = Southampton
#
# #### Variable Notes
#
# 1. pclass: A proxy for socio-economic status (SES)
#     * 1st = Upper
#     * 2nd = Middle
#     * 3rd = Lower
#
# 2. age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# 3. sibsp: The dataset defines family relations in this way...
#     * Sibling = brother, sister, stepbrother, stepsister
#     * Spouse = husband, wife (mistresses and fiancés were ignored)
#
# 4. parch: The dataset defines family relations in this way...
#     * Parent = mother, father
#     * Child = daughter, son, stepdaughter, stepson
#     * Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
#plotting library built on matplotlib
import seaborn as sns

# %%
df = pd.read_csv(r'Data\titanic\train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Are there any missing values
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_temp = df.copy()
df_temp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Find which columns are string
for label, content in df_temp.items():
    if pd.api.types.is_string_dtype(content):
        print (label)
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked

# %%
# Turning string values into categorical values
for label, content in df_temp.items():
    if pd.api.types.is_string_dtype(content):
        df_temp[label] = content.astype("category").cat.as_ordered()

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    category
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    category
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    category
#  11  Embarked     889 non-null    category
# dtypes: category(5), float64(2), int64(5)
# memory usage: 134.4 KB

# %%
df_temp['Sex'].cat.categories
# Out:
# Index(['female', 'male'], dtype='object')

# %%
df_temp.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df_temp['Cabin'].cat.categories
# Out:
# Index(['A10', 'A14', 'A16', 'A19', 'A20', 'A23', 'A24', 'A26', 'A31', 'A32',
#        ...
#        'E8', 'F E69', 'F G63', 'F G73', 'F2', 'F33', 'F38', 'F4', 'G6', 'T'],
#       dtype='object', length=147)

# %%
df_temp['Sex'].cat.codes  
# 1- male ,  0- female
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Length: 891, dtype: int8

# %%
# finding missing data count
df_temp.isna().sum() / len(df_temp)
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %% [markdown]
# ### Filling missing values
#
# #### Filling numerical missing values first

# %%
# See al numeric columns
for label, content in df_temp.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# PassengerId
# Survived
# Pclass
# Age
# SibSp
# Parch
# Fare

# %%
# Checking if numeric columns have null values
for label, content in df_temp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# Age

# %%
# Fill numeric rows with median

for label, content in df_temp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Add binary column to check if it was empty before
            df_temp[label+"_is_missing"] = pd.isna(content)
            # fill missing value with median
            df_temp[label] = content.fillna(content.median())

# %%
df_temp["Age_is_missing"].value_counts()
# Out:
# False    714
# True     177
# Name: Age_is_missing, dtype: int64

# %% [markdown]
# #### Filling and turning categorical values into numbers

# %%
for label,content in df_temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked

# %%
# Now see which non numeric columns have empty values

for label,content in df_temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# Cabin
# Embarked

# %%
# Turning categorical to numbers and filling missing

for label,content in df_temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        # Add binary column to check whehter it was empty or not
        df_temp[label+"_is_missing"] = pd.isna(content)
        # Turn categories to numbers and add +1
        df_temp[label] = pd.Categorical(content).codes+1
        
'''
+1 is added in the codes because, while converting to numerical, if there is no value, then it results in -1. So adding a 1 will
amount to 0 and negative values will not appear.
'''
# Out:
# '\n+1 is added in the codes because, while converting to numerical, if there is no value, then it results in -1. So adding a 1 will\namount to 0 and negative values will not appear.\n'

# %%
df_temp.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   109    2  22.0      1      0     524
# 1            2         1       1   191    1  38.0      1      0     597
# 2            3         1       3   354    1  26.0      0      0     670
# 3            4         1       1   273    1  35.0      1      0      50
# 4            5         0       3    16    2  35.0      0      0     473
#
#       Fare  Cabin  Embarked  Age_is_missing  Name_is_missing  Sex_is_missing  \
# 0   7.2500      0         3           False            False           False
# 1  71.2833     82         1           False            False           False
# 2   7.9250      0         3           False            False           False
# 3  53.1000     56         3           False            False           False
# 4   8.0500      0         3           False            False           False
#
#    Ticket_is_missing  Cabin_is_missing  Embarked_is_missing
# ...

# %%
df_temp.isna().sum()
# Out:
# PassengerId            0
# Survived               0
# Pclass                 0
# Name                   0
# Sex                    0
# Age                    0
# SibSp                  0
# Parch                  0
# Ticket                 0
# Fare                   0
# Cabin                  0
# Embarked               0
# Age_is_missing         0
# Name_is_missing        0
# Sex_is_missing         0
# Ticket_is_missing      0
# Cabin_is_missing       0
# Embarked_is_missing    0
# dtype: int64

# %%
pd.crosstab(df_temp.Survived, df_temp.Sex)
# Out:
# Sex         1    2
# Survived
# 0          81  468
# 1         233  109

# %%
# plot for crosstab for Sex
pd.crosstab(df_temp.Survived, df_temp.Sex).plot(kind='bar',
                                               figsize= (5,5),
                                               color=['salmon', 'lightblue']);
plt.title("Gender based survival graph")
plt.legend(['Female', 'Male'])
plt.xlabel('0-died and 1-survived')
plt.ylabel("Number of people")
plt.xticks(rotation=0);

# %%
# plot for crosstab for Sex
pd.crosstab(df_temp.Survived, df_temp.Pclass).plot(kind='bar',
                                               figsize= (8,5),
                                               color=['salmon', 'lightblue', 'lightgreen']);
plt.title("Class based survival graph")
plt.legend(['First', 'Second', 'Third'])
plt.xlabel('0-died and 1-survived')
plt.ylabel("Number of people")
plt.xticks(rotation=0);

# %%
df_new = df_temp.drop(['Age_is_missing', 'Name_is_missing', 'Sex_is_missing', 'Ticket_is_missing', 'Cabin_is_missing',
                      'Embarked_is_missing'], axis=1)

# %%
df_new.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   109    2  22.0      1      0     524
# 1            2         1       1   191    1  38.0      1      0     597
# 2            3         1       3   354    1  26.0      0      0     670
# 3            4         1       1   273    1  35.0      1      0      50
# 4            5         0       3    16    2  35.0      0      0     473
#
#       Fare  Cabin  Embarked
# 0   7.2500      0         3
# 1  71.2833     82         1
# 2   7.9250      0         3
# 3  53.1000     56         3
# 4   8.0500      0         3

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int16
#  4   Sex          891 non-null    int8
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int16
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    int16
#  11  Embarked     891 non-null    int8
# dtypes: float64(2), int16(3), int64(5), int8(2)
# memory usage: 55.8 KB

# %%
df_new.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.034212
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.064910
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.339898
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.048252
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.081163
# Age             0.034212 -0.064910 -0.339898  0.048252  0.081163  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.233296
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.172482
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.070382
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.096688
# Cabin          -0.000637  0.276235 -0.537419  0.003122 -0.137704  0.164550
# ...

# %%
# Lets make correlation matrix prettier
# higher positive value means positive correlation
# Higher negative value means lower correlation
# Negative correlation - in which one variable decreases and other increases
# Positive correlation - in which as one variabe goes up, other also goes up

import seaborn as sns 

corr_matrix = df_new.corr()
fig, ax = plt.subplots(figsize=(15,10))

ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt='.2f',
                cmap='YlGnBu');

# %%
# Split the data

X = df_new.drop(['Survived'], axis = 1)
y = df_new.Survived

# %%
X
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3   109    2  22.0      1      0     524   7.2500
# 1              2       1   191    1  38.0      1      0     597  71.2833
# 2              3       3   354    1  26.0      0      0     670   7.9250
# 3              4       1   273    1  35.0      1      0      50  53.1000
# 4              5       3    16    2  35.0      0      0     473   8.0500
# ..           ...     ...   ...  ...   ...    ...    ...     ...      ...
# 886          887       2   549    2  27.0      0      0     102  13.0000
# 887          888       1   304    1  19.0      0      0      15  30.0000
# 888          889       3   414    1  28.0      1      2     676  23.4500
# 889          890       1    82    2  26.0      0      0       9  30.0000
# 890          891       3   221    2  32.0      0      0     467   7.7500
#
#      Cabin  Embarked
# 0        0         3
# 1       82         1
# 2        0         3
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Models from scikit learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# Model evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve, roc_auc_score

# %%
# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
#      PassengerId  Pclass  Name  Sex    Age  SibSp  Parch  Ticket    Fare  \
# 538          539       3   693    2  28.00      0      0     427  14.500
# 791          792       2   279    2  16.00      0      0     140  26.000
# 804          805       3   352    2  27.00      0      0     339   6.975
# 379          380       3   315    2  19.00      0      0     325   7.775
# 809          810       1   153    1  33.00      1      0      52  53.100
# ..           ...     ...   ...  ...    ...    ...    ...     ...     ...
# 461          462       3   558    2  34.00      0      0     430   8.050
# 489          490       3   183    2   9.00      1      1     563  15.900
# 480          481       3   298    2   9.00      5      2     567  46.900
# 317          318       2   556    2  54.00      0      0     233  14.000
# 755          756       2   322    2   0.67      1      1     167  14.500
#
#      Cabin  Embarked
# 538      0         3
# 791      0         3
# 804      0         3
# ...

# %%
# Put models in a dictionary
np.random.seed(42)
models = {'Logistic Regression': LogisticRegression(),
         'KNN': KNeighborsClassifier(),
         'Random FOrest Classifer': RandomForestClassifier()}

# Create a fucntion to use all these models to train data and evaluate on validation set
def gen_model_score(models, X_train, X_val, y_train, y_val):
    model_score= {}
    for modelname, model in models.items():
        model.fit(X_train, y_train)
        model_score[modelname] = model.score(X_val, y_val)
    return model_score

# %%
gen_model_score(models, X_train = X_train, X_val= X_val, y_train= y_train, y_val= y_val)
# Out:
# C:\Users\iamrr\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# {'Logistic Regression': 0.7486033519553073,
#  'KNN': 0.6201117318435754,
#  'Random FOrest Classifer': 0.8268156424581006}

# %%
# creating hyperparameters grid for RandomForestClassifier
rf_grid = {'n_estimators': np.arange(10,1000,50),
           'max_depth': [None,3,5,10],
           'min_samples_split': np.arange(2,20,2),
           'min_samples_leaf':np.arange(1,20,2)}

# %%
# Hyperparameter tuning with Randomized Search CV
np.random.seed(42)
rs_random_forest = RandomizedSearchCV(RandomForestClassifier(),
                                      param_distributions= rf_grid,
                                      cv=5,
                                      n_iter = 20,
                                      verbose = True)
rs_random_forest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  2.6min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
# ...

# %%
rs_random_forest.best_params_
# Out:
# {'n_estimators': 510,
#  'min_samples_split': 14,
#  'min_samples_leaf': 1,
#  'max_depth': None}

# %%
rs_random_forest.score(X_val, y_val)
# Out:
# 0.8100558659217877

# %%
# HYperparameter tuning with GridSearchCV

# creating hyperparameters grid for RandomForestClassifier
rf_gs_grid = {'n_estimators': [510,400,600],
           'max_depth': [None],
           'min_samples_split': np.arange(12,16,2),
           'min_samples_leaf':[1,2]}

gs_rf = GridSearchCV( RandomForestClassifier(),
                          param_grid= rf_gs_grid,
                         cv=5,
                         verbose=True)

gs_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  1.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
# ...

# %%
gs_rf.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 12,
#  'n_estimators': 400}

# %%
gs_rf.score(X_val, y_val)
# Out:
# 0.8212290502793296

# %% [markdown]
# #### Making predictions on Test Data

# %%
df_test = pd.read_csv(r'Data\titanic\test.csv')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# finding string columns 
for label, content in df_test.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked

# %%
# Turning string values into categorical values
for label, content in df_test.items():
    if pd.api.types.is_string_dtype(content):
        df_test[label] = content.astype("category").cat.as_ordered()

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    category
#  3   Sex          418 non-null    category
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    category
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     category
#  10  Embarked     418 non-null    category
# dtypes: category(5), float64(2), int64(4)
# memory usage: 62.0 KB

# %%
df_test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Find out numeric columns that have missign values
for label, content in df_test.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# Age
# Fare

# %%
# Fill numeric rows with median

for label, content in df_test.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Add binary column to check if it was empty before
            df_test[label+"_is_missing"] = pd.isna(content)
            # fill missing value with median
            df_test[label] = content.fillna(content.median())

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Age_is_missing  \
# 0  34.5      0      0   330911   7.8292   NaN        Q           False
# 1  47.0      1      0   363272   7.0000   NaN        S           False
# 2  62.0      0      0   240276   9.6875   NaN        Q           False
# 3  27.0      0      0   315154   8.6625   NaN        S           False
# 4  22.0      1      1  3101298  12.2875   NaN        S           False
#
#    Fare_is_missing
# 0            False
# 1            False
# ...

# %%
# Find out category columns that have missign values
for label, content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# Cabin

# %%
# Turning categorical to numbers and filling missing

for label,content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        # Add binary column to check whehter it was empty or not
        df_test[label+"_is_missing"] = pd.isna(content)
        # Turn categories to numbers and add +1
        df_test[label] = pd.Categorical(content).codes+1

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0          892       3   207    2  34.5      0      0     153   7.8292      0
# 1          893       3   404    1  47.0      1      0     222   7.0000      0
# 2          894       2   270    2  62.0      0      0      74   9.6875      0
# 3          895       3   409    2  27.0      0      0     148   8.6625      0
# 4          896       3   179    1  22.0      1      1     139  12.2875      0
#
#    Embarked  Age_is_missing  Fare_is_missing  Name_is_missing  Sex_is_missing  \
# 0         2           False            False            False           False
# 1         3           False            False            False           False
# 2         2           False            False            False           False
# 3         3           False            False            False           False
# 4         3           False            False            False           False
#
# ...

# %%
df_test.isna().sum()
# Out:
# PassengerId            0
# Pclass                 0
# Name                   0
# Sex                    0
# Age                    0
# SibSp                  0
# Parch                  0
# Ticket                 0
# Fare                   0
# Cabin                  0
# Embarked               0
# Age_is_missing         0
# Fare_is_missing        0
# Name_is_missing        0
# Sex_is_missing         0
# Ticket_is_missing      0
# Cabin_is_missing       0
# Embarked_is_missing    0
# dtype: int64

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0          892       3   207    2  34.5      0      0     153   7.8292      0
# 1          893       3   404    1  47.0      1      0     222   7.0000      0
# 2          894       2   270    2  62.0      0      0      74   9.6875      0
# 3          895       3   409    2  27.0      0      0     148   8.6625      0
# 4          896       3   179    1  22.0      1      1     139  12.2875      0
#
#    Embarked  Age_is_missing  Fare_is_missing  Name_is_missing  Sex_is_missing  \
# 0         2           False            False            False           False
# 1         3           False            False            False           False
# 2         2           False            False            False           False
# 3         3           False            False            False           False
# 4         3           False            False            False           False
#
# ...

# %%
df_pred = df_test.drop(['Age_is_missing', 'Name_is_missing', 'Sex_is_missing', 'Ticket_is_missing', 'Cabin_is_missing',
                      'Embarked_is_missing', 'Fare_is_missing'], axis=1)

# %%
df_pred.head()
# Out:
#    PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0          892       3   207    2  34.5      0      0     153   7.8292      0
# 1          893       3   404    1  47.0      1      0     222   7.0000      0
# 2          894       2   270    2  62.0      0      0      74   9.6875      0
# 3          895       3   409    2  27.0      0      0     148   8.6625      0
# 4          896       3   179    1  22.0      1      1     139  12.2875      0
#
#    Embarked
# 0         2
# 1         3
# 2         2
# 3         3
# 4         3

# %%
y_preds = gs_rf.predict(df_pred)

# %%
y_preds[:5]
# Out:
# array([0, 0, 0, 0, 1], dtype=int64)

# %%
len(y_preds)
# Out:
# 418

# %%
df_submit = pd.DataFrame()
df_submit["PassengerId"] = df_pred['PassengerId']
df_submit["Survived"] = y_preds

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# Export prediciton data
df_submit.to_csv('Data\OutputSubmission\submission.csv', index = False)
